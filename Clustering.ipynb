# %%
from sklearn.datasets import make_blobs  
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from matplotlib import cm
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

# Problem 1: Determine the initial value of the center point
# ----------------------------------------------------------
X, _ = make_blobs(n_samples=100, n_features=2, centers=4, cluster_std=0.5, shuffle=True, random_state=0)


# Problem 6: Calculation with different initial values
# ----------------------------------------------------
class ScratchKMeans():
    def __init__(self, n_clusters=2,n_init=20,n_iter=100,verbose=False):
        self.n_clusters = n_clusters
        self.n_init = n_init
        self.n_iter = n_iter
        self.verbose = verbose
        self.best_sse = 10**20
        
# Problem 2:  Creating a function to find SSE
# -------------------------------------------
    def calc_sse(self,X):
            sse = 0
            for i in range(len(X)):
                for j in range(self.n_clusters):
                    if j == X[i,-1]:
                        sse += np.sum((X[i,:-1]-self.myu[j])**2)
            if self.best_sse > sse:
                self.best_sse = sse
                self.record_myu = self.myu
                self.record_cluster = self.n_clusters
            
# Problem 3: Assignment to a cluster
# ----------------------------------
    def _update_cluster(self,X):
            for i in range(len(X)):
                dist_m = 10**20
                for j in range(self.n_clusters):
                    dist = np.sqrt(np.sum((X[i,:-1]-self.myu[j])**2))
                    if dist < dist_m:
                        dist_m = dist
                        X[i,-1] = j
                    
# Problem 4: Moving the center point
# ----------------------------------
    def _update_myu(self,X):
            for j in range(self.n_clusters):
                self.myu[j] = np.mean(X[X[:,-1]==j,:-1],axis=0)

# Question 5: Repeat
# ------------------
    def fit(self, X):
        for i in range(self.n_init):
            self.myu = X[np.random.choice(len(X),size=self.n_clusters,replace=False)]
            cluster = np.zeros(len(X))
            X_cluster = np.concatenate([X,cluster.reshape(-1,1)],axis=1)
            for j in range(self.n_iter):
                self.calc_sse(X_cluster)
                self._update_cluster(X_cluster)
                self._update_myu(X_cluster)
                if self.verbose:
                    print("Initialization：%s　Learning times：%s　Best SSE：%s"%(i,j,self.best_sse))
                    
# Question 7: Estimation
# ----------------------
    def predict(self, X):
        y_pred = np.zeros(len(X))
        for i in range(len(X)):
            dist_m = 10**20
            for j in range(self.record_cluster):
                dist = np.sqrt(np.sum((X[i]-self.record_myu[j])**2))
                if dist < dist_m:
                    dist_m = dist
                    y_pred[i] = j
        return y_pred

# Question 10: Selection of the number of clusters k
# --------------------------------------------------
data = pd.read_csv('Wholesale customers data.csv')
X = data[['Fresh', 'Milk', 'Grocery', 'Frozen','Detergents_Paper', 'Delicassen']].values

X_train, X_valid = \
train_test_split(X,train_size=0.8,random_state=None)
clf = ScratchKMeans(n_clusters=4,n_init=5,n_iter=100,verbose=True)
clf.fit(X_train)
pred = clf.predict(X_valid)

# Problem 8: Implementation of the Elbow Method
# ---------------------------------------------
elbow = {}
for k in range(1,8):
    model = ScratchKMeans(n_clusters=k,n_init=5,n_iter=100,verbose=False)
    model.fit(X)
    elbow[k] = model.best_sse
fig = plt.subplots(figsize=(12,8))
plt.rcParams["font.size"] = 20
plt.plot(list(elbow.keys()),list(elbow.values()),'rs--');

clf = ScratchKMeans(n_clusters=4,n_init=5,n_iter=100,verbose=False)
clf.fit(X)
pred = clf.predict(X)
summary_df = pd.DataFrame({'pred':pred,'Region':data['Region'],'Channel':data['Channel'],})

# Question 11:  Comparison with known groups
# ------------------------------------------
clf = ScratchKMeans(n_clusters=4,n_init=5,n_iter=100,verbose=False)
clf.fit(X)
pred = clf.predict(X)
summary_df = pd.DataFrame({'pred':pred,'Region':data['Region'],'Channel':data['Channel'],})
pd.pivot_table(summary_df, index='Region', columns='pred',values='Channel', aggfunc=len)
pd.pivot_table(summary_df, index='Channel', columns='pred',values='Region', aggfunc=len)

# Question 12: Information useful for wholesalers
# -----------------------------------------------
data['cluster'] = pred
data.groupby('cluster').agg(['mean'])

#  Problem 9: (Advance assignment) Silhouette diagram 
#  --------------------------------------------------
# Generating the sample data from make_blobs
# This particular setting has one distinct cluster and 3 clusters placed close
# together.
X, y = make_blobs(n_samples=500,
                  n_features=2,
                  centers=4,
                  cluster_std=1,
                  center_box=(-10.0, 10.0),
                  shuffle=True,
                  random_state=1)  # For reproducibility

range_n_clusters = [2, 3, 4, 5, 6]

from sklearn.cluster import KMeans

wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

clusterer = KMeans(n_clusters=4, random_state=10)
cluster_labels = clusterer.fit_predict(X)
print(cluster_labels)

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()

# Problem 13: (Advance assignment) Investigation of other methods
# ---------------------------------------------------------------
# What are the advantages and disadvantages of DBSCAN?
# ---------------------------------------------------
#    While DBSCAN is great at separating high-density clusters from low-density clusters, DBSCAN struggles with clusters of similar density.
#    Struggles with high dimensionality data. If given data with too many dimensions, DBSCAN suffers.
# 
# Advantages of t-SNE
# ------------------
# 1. Handles Non Linear Data Efficiently
# 2. Preserves Local and Global Structure
# 
# Disadvantages of t-SNE
# ----------------------
# 1. Computationally Complex
# 2. Non-deterministic
# 3. Requires Hyperparameter Tuning
# 4. Noisy Patterns
#
# Problem 14: (Advance assignment) Use of t-SNE and DBSCAN
# --------------------------------------------------------
# Configuration options
num_samples_total = 1000
cluster_centers = [(3,3), (7,7)]
num_classes = len(cluster_centers)
epsilon = 1.0
min_samples = 13

# Generate data
X, y = make_blobs(n_samples = num_samples_total, centers = cluster_centers, n_features = num_classes, center_box=(0, 1), cluster_std = 0.5)

# Compute DBSCAN
db = DBSCAN(eps=epsilon, min_samples=min_samples).fit(X)
labels = db.labels_

no_clusters = len(np.unique(labels) )
no_noise = np.sum(np.array(labels) == -1, axis=0)

print('Estimated no. of clusters: %d' % no_clusters)
print('Estimated no. of noise points: %d' % no_noise)
# Out:
# Initialization：0　Learning times：0　Best SSE：171875924551.0
# Initialization：0　Learning times：1　Best SSE：104039807263.0
# Initialization：0　Learning times：2　Best SSE：88680645917.0
# Initialization：0　Learning times：3　Best SSE：75597526890.0
# Initialization：0　Learning times：4　Best SSE：68957975147.0
# Initialization：0　Learning times：5　Best SSE：65733947800.0
# Initialization：0　Learning times：6　Best SSE：63776629201.0
# Initialization：0　Learning times：7　Best SSE：61315607389.0
# Initialization：0　Learning times：8　Best SSE：60188309553.0
# Initialization：0　Learning times：9　Best SSE：59898397437.0
# Initialization：0　Learning times：10　Best SSE：59859809207.0
# Initialization：0　Learning times：11　Best SSE：59734895417.0
# Initialization：0　Learning times：12　Best SSE：59665391600.0
# Initialization：0　Learning times：13　Best SSE：59579929753.0
# Initialization：0　Learning times：14　Best SSE：59371206512.0
# Initialization：0　Learning times：15　Best SSE：59335901689.0
# Initialization：0　Learning times：16　Best SSE：59335901689.0
# Initialization：0　Learning times：17　Best SSE：59335901689.0
# Initialization：0　Learning times：18　Best SSE：59335901689.0
# Initialization：0　Learning times：19　Best SSE：59335901689.0
# Initialization：0　Learning times：20　Best SSE：59335901689.0
# Initialization：0　Learning times：21　Best SSE：59335901689.0
# Initialization：0　Learning times：22　Best SSE：59335901689.0
# Initialization：0　Learning times：23　Best SSE：59335901689.0
# Initialization：0　Learning times：24　Best SSE：59335901689.0
# Initialization：0　Learning times：25　Best SSE：59335901689.0
# Initialization：0　Learning times：26　Best SSE：59335901689.0
# Initialization：0　Learning times：27　Best SSE：59335901689.0
# Initialization：0　Learning times：28　Best SSE：59335901689.0
# Initialization：0　Learning times：29　Best SSE：59335901689.0
# Initialization：0　Learning times：30　Best SSE：59335901689.0
# Initialization：0　Learning times：31　Best SSE：59335901689.0
# Initialization：0　Learning times：32　Best SSE：59335901689.0
# Initialization：0　Learning times：33　Best SSE：59335901689.0
# Initialization：0　Learning times：34　Best SSE：59335901689.0
# Initialization：0　Learning times：35　Best SSE：59335901689.0
# Initialization：0　Learning times：36　Best SSE：59335901689.0
# Initialization：0　Learning times：37　Best SSE：59335901689.0
# Initialization：0　Learning times：38　Best SSE：59335901689.0
# Initialization：0　Learning times：39　Best SSE：59335901689.0
# Initialization：0　Learning times：40　Best SSE：59335901689.0
# Initialization：0　Learning times：41　Best SSE：59335901689.0
# Initialization：0　Learning times：42　Best SSE：59335901689.0
# Initialization：0　Learning times：43　Best SSE：59335901689.0
# Initialization：0　Learning times：44　Best SSE：59335901689.0
# Initialization：0　Learning times：45　Best SSE：59335901689.0
# Initialization：0　Learning times：46　Best SSE：59335901689.0
# Initialization：0　Learning times：47　Best SSE：59335901689.0
# Initialization：0　Learning times：48　Best SSE：59335901689.0
# Initialization：0　Learning times：49　Best SSE：59335901689.0
# Initialization：0　Learning times：50　Best SSE：59335901689.0
# Initialization：0　Learning times：51　Best SSE：59335901689.0
# Initialization：0　Learning times：52　Best SSE：59335901689.0
# Initialization：0　Learning times：53　Best SSE：59335901689.0
# Initialization：0　Learning times：54　Best SSE：59335901689.0
# Initialization：0　Learning times：55　Best SSE：59335901689.0
# Initialization：0　Learning times：56　Best SSE：59335901689.0
# Initialization：0　Learning times：57　Best SSE：59335901689.0
# Initialization：0　Learning times：58　Best SSE：59335901689.0
# Initialization：0　Learning times：59　Best SSE：59335901689.0
# Initialization：0　Learning times：60　Best SSE：59335901689.0
# Initialization：0　Learning times：61　Best SSE：59335901689.0
# Initialization：0　Learning times：62　Best SSE：59335901689.0
# Initialization：0　Learning times：63　Best SSE：59335901689.0
# Initialization：0　Learning times：64　Best SSE：59335901689.0
# Initialization：0　Learning times：65　Best SSE：59335901689.0
# Initialization：0　Learning times：66　Best SSE：59335901689.0
# Initialization：0　Learning times：67　Best SSE：59335901689.0
# Initialization：0　Learning times：68　Best SSE：59335901689.0
# Initialization：0　Learning times：69　Best SSE：59335901689.0
# Initialization：0　Learning times：70　Best SSE：59335901689.0
# Initialization：0　Learning times：71　Best SSE：59335901689.0
# Initialization：0　Learning times：72　Best SSE：59335901689.0
# Initialization：0　Learning times：73　Best SSE：59335901689.0
# Initialization：0　Learning times：74　Best SSE：59335901689.0
# Initialization：0　Learning times：75　Best SSE：59335901689.0
# Initialization：0　Learning times：76　Best SSE：59335901689.0
# Initialization：0　Learning times：77　Best SSE：59335901689.0
# Initialization：0　Learning times：78　Best SSE：59335901689.0
# Initialization：0　Learning times：79　Best SSE：59335901689.0
# Initialization：0　Learning times：80　Best SSE：59335901689.0
# Initialization：0　Learning times：81　Best SSE：59335901689.0
# Initialization：0　Learning times：82　Best SSE：59335901689.0
# Initialization：0　Learning times：83　Best SSE：59335901689.0
# Initialization：0　Learning times：84　Best SSE：59335901689.0
# Initialization：0　Learning times：85　Best SSE：59335901689.0
# Initialization：0　Learning times：86　Best SSE：59335901689.0
# Initialization：0　Learning times：87　Best SSE：59335901689.0
# Initialization：0　Learning times：88　Best SSE：59335901689.0
# Initialization：0　Learning times：89　Best SSE：59335901689.0
# Initialization：0　Learning times：90　Best SSE：59335901689.0
# Initialization：0　Learning times：91　Best SSE：59335901689.0
# Initialization：0　Learning times：92　Best SSE：59335901689.0
# Initialization：0　Learning times：93　Best SSE：59335901689.0
# Initialization：0　Learning times：94　Best SSE：59335901689.0
# Initialization：0　Learning times：95　Best SSE：59335901689.0
# Initialization：0　Learning times：96　Best SSE：59335901689.0
# Initialization：0　Learning times：97　Best SSE：59335901689.0
# Initialization：0　Learning times：98　Best SSE：59335901689.0
# Initialization：0　Learning times：99　Best SSE：59335901689.0
# Initialization：1　Learning times：0　Best SSE：59335901689.0
# Initialization：1　Learning times：1　Best SSE：59335901689.0
# Initialization：1　Learning times：2　Best SSE：59335901689.0
# Initialization：1　Learning times：3　Best SSE：59335901689.0
# Initialization：1　Learning times：4　Best SSE：59335901689.0
# Initialization：1　Learning times：5　Best SSE：59335901689.0
# Initialization：1　Learning times：6　Best SSE：59335901689.0
# Initialization：1　Learning times：7　Best SSE：59335901689.0
# Initialization：1　Learning times：8　Best SSE：59335901689.0
# Initialization：1　Learning times：9　Best SSE：58808656694.0
# Initialization：1　Learning times：10　Best SSE：58750183497.0
# Initialization：1　Learning times：11　Best SSE：58733733112.0
# Initialization：1　Learning times：12　Best SSE：58732199824.0
# Initialization：1　Learning times：13　Best SSE：58732199824.0
# Initialization：1　Learning times：14　Best SSE：58732199824.0
# Initialization：1　Learning times：15　Best SSE：58732199824.0
# Initialization：1　Learning times：16　Best SSE：58732199824.0
# Initialization：1　Learning times：17　Best SSE：58732199824.0
# Initialization：1　Learning times：18　Best SSE：58732199824.0
# Initialization：1　Learning times：19　Best SSE：58732199824.0
# Initialization：1　Learning times：20　Best SSE：58732199824.0
# Initialization：1　Learning times：21　Best SSE：58732199824.0
# Initialization：1　Learning times：22　Best SSE：58732199824.0
# Initialization：1　Learning times：23　Best SSE：58732199824.0
# Initialization：1　Learning times：24　Best SSE：58732199824.0
# Initialization：1　Learning times：25　Best SSE：58732199824.0
# Initialization：1　Learning times：26　Best SSE：58732199824.0
# Initialization：1　Learning times：27　Best SSE：58732199824.0
# Initialization：1　Learning times：28　Best SSE：58732199824.0
# Initialization：1　Learning times：29　Best SSE：58732199824.0
# Initialization：1　Learning times：30　Best SSE：58732199824.0
# Initialization：1　Learning times：31　Best SSE：58732199824.0
# Initialization：1　Learning times：32　Best SSE：58732199824.0
# Initialization：1　Learning times：33　Best SSE：58732199824.0
# Initialization：1　Learning times：34　Best SSE：58732199824.0
# Initialization：1　Learning times：35　Best SSE：58732199824.0
# Initialization：1　Learning times：36　Best SSE：58732199824.0
# Initialization：1　Learning times：37　Best SSE：58732199824.0
# Initialization：1　Learning times：38　Best SSE：58732199824.0
# Initialization：1　Learning times：39　Best SSE：58732199824.0
# Initialization：1　Learning times：40　Best SSE：58732199824.0
# Initialization：1　Learning times：41　Best SSE：58732199824.0
# Initialization：1　Learning times：42　Best SSE：58732199824.0
# Initialization：1　Learning times：43　Best SSE：58732199824.0
# Initialization：1　Learning times：44　Best SSE：58732199824.0
# Initialization：1　Learning times：45　Best SSE：58732199824.0
# Initialization：1　Learning times：46　Best SSE：58732199824.0
# Initialization：1　Learning times：47　Best SSE：58732199824.0
# Initialization：1　Learning times：48　Best SSE：58732199824.0
# Initialization：1　Learning times：49　Best SSE：58732199824.0
# Initialization：1　Learning times：50　Best SSE：58732199824.0
# Initialization：1　Learning times：51　Best SSE：58732199824.0
# Initialization：1　Learning times：52　Best SSE：58732199824.0
# Initialization：1　Learning times：53　Best SSE：58732199824.0
# Initialization：1　Learning times：54　Best SSE：58732199824.0
# Initialization：1　Learning times：55　Best SSE：58732199824.0
# Initialization：1　Learning times：56　Best SSE：58732199824.0
# Initialization：1　Learning times：57　Best SSE：58732199824.0
# Initialization：1　Learning times：58　Best SSE：58732199824.0
# Initialization：1　Learning times：59　Best SSE：58732199824.0
# Initialization：1　Learning times：60　Best SSE：58732199824.0
# Initialization：1　Learning times：61　Best SSE：58732199824.0
# Initialization：1　Learning times：62　Best SSE：58732199824.0
# Initialization：1　Learning times：63　Best SSE：58732199824.0
# Initialization：1　Learning times：64　Best SSE：58732199824.0
# Initialization：1　Learning times：65　Best SSE：58732199824.0
# Initialization：1　Learning times：66　Best SSE：58732199824.0
# Initialization：1　Learning times：67　Best SSE：58732199824.0
# Initialization：1　Learning times：68　Best SSE：58732199824.0
# Initialization：1　Learning times：69　Best SSE：58732199824.0
# Initialization：1　Learning times：70　Best SSE：58732199824.0
# Initialization：1　Learning times：71　Best SSE：58732199824.0
# Initialization：1　Learning times：72　Best SSE：58732199824.0
# Initialization：1　Learning times：73　Best SSE：58732199824.0
# Initialization：1　Learning times：74　Best SSE：58732199824.0
# Initialization：1　Learning times：75　Best SSE：58732199824.0
# Initialization：1　Learning times：76　Best SSE：58732199824.0
# Initialization：1　Learning times：77　Best SSE：58732199824.0
# Initialization：1　Learning times：78　Best SSE：58732199824.0
# Initialization：1　Learning times：79　Best SSE：58732199824.0
# Initialization：1　Learning times：80　Best SSE：58732199824.0
# Initialization：1　Learning times：81　Best SSE：58732199824.0
# Initialization：1　Learning times：82　Best SSE：58732199824.0
# Initialization：1　Learning times：83　Best SSE：58732199824.0
# Initialization：1　Learning times：84　Best SSE：58732199824.0
# Initialization：1　Learning times：85　Best SSE：58732199824.0
# Initialization：1　Learning times：86　Best SSE：58732199824.0
# Initialization：1　Learning times：87　Best SSE：58732199824.0
# Initialization：1　Learning times：88　Best SSE：58732199824.0
# Initialization：1　Learning times：89　Best SSE：58732199824.0
# Initialization：1　Learning times：90　Best SSE：58732199824.0
# Initialization：1　Learning times：91　Best SSE：58732199824.0
# Initialization：1　Learning times：92　Best SSE：58732199824.0
# Initialization：1　Learning times：93　Best SSE：58732199824.0
# Initialization：1　Learning times：94　Best SSE：58732199824.0
# Initialization：1　Learning times：95　Best SSE：58732199824.0
# Initialization：1　Learning times：96　Best SSE：58732199824.0
# Initialization：1　Learning times：97　Best SSE：58732199824.0
# Initialization：1　Learning times：98　Best SSE：58732199824.0
# Initialization：1　Learning times：99　Best SSE：58732199824.0
# Initialization：2　Learning times：0　Best SSE：58732199824.0
# Initialization：2　Learning times：1　Best SSE：58732199824.0
# Initialization：2　Learning times：2　Best SSE：58732199824.0
# Initialization：2　Learning times：3　Best SSE：58732199824.0
# Initialization：2　Learning times：4　Best SSE：57921794179.0
# Initialization：2　Learning times：5　Best SSE：57293544370.0
# Initialization：2　Learning times：6　Best SSE：57163788954.0
# Initialization：2　Learning times：7　Best SSE：57083936600.0
# Initialization：2　Learning times：8　Best SSE：57062252027.0
# Initialization：2　Learning times：9　Best SSE：57019521419.0
# Initialization：2　Learning times：10　Best SSE：56999980725.0
# Initialization：2　Learning times：11　Best SSE：56999980725.0
# Initialization：2　Learning times：12　Best SSE：56999980725.0
# Initialization：2　Learning times：13　Best SSE：56999980725.0
# Initialization：2　Learning times：14　Best SSE：56999980725.0
# Initialization：2　Learning times：15　Best SSE：56999980725.0
# Initialization：2　Learning times：16　Best SSE：56999980725.0
# Initialization：2　Learning times：17　Best SSE：56999980725.0
# Initialization：2　Learning times：18　Best SSE：56999980725.0
# Initialization：2　Learning times：19　Best SSE：56999980725.0
# Initialization：2　Learning times：20　Best SSE：56999980725.0
# Initialization：2　Learning times：21　Best SSE：56999980725.0
# Initialization：2　Learning times：22　Best SSE：56999980725.0
# Initialization：2　Learning times：23　Best SSE：56999980725.0
# Initialization：2　Learning times：24　Best SSE：56999980725.0
# Initialization：2　Learning times：25　Best SSE：56999980725.0
# Initialization：2　Learning times：26　Best SSE：56999980725.0
# Initialization：2　Learning times：27　Best SSE：56999980725.0
# Initialization：2　Learning times：28　Best SSE：56999980725.0
# Initialization：2　Learning times：29　Best SSE：56999980725.0
# Initialization：2　Learning times：30　Best SSE：56999980725.0
# Initialization：2　Learning times：31　Best SSE：56999980725.0
# Initialization：2　Learning times：32　Best SSE：56999980725.0
# Initialization：2　Learning times：33　Best SSE：56999980725.0
# Initialization：2　Learning times：34　Best SSE：56999980725.0
# Initialization：2　Learning times：35　Best SSE：56999980725.0
# Initialization：2　Learning times：36　Best SSE：56999980725.0
# Initialization：2　Learning times：37　Best SSE：56999980725.0
# Initialization：2　Learning times：38　Best SSE：56999980725.0
# Initialization：2　Learning times：39　Best SSE：56999980725.0
# Initialization：2　Learning times：40　Best SSE：56999980725.0
# Initialization：2　Learning times：41　Best SSE：56999980725.0
# Initialization：2　Learning times：42　Best SSE：56999980725.0
# Initialization：2　Learning times：43　Best SSE：56999980725.0
# Initialization：2　Learning times：44　Best SSE：56999980725.0
# Initialization：2　Learning times：45　Best SSE：56999980725.0
# Initialization：2　Learning times：46　Best SSE：56999980725.0
# Initialization：2　Learning times：47　Best SSE：56999980725.0
# Initialization：2　Learning times：48　Best SSE：56999980725.0
# Initialization：2　Learning times：49　Best SSE：56999980725.0
# Initialization：2　Learning times：50　Best SSE：56999980725.0
# Initialization：2　Learning times：51　Best SSE：56999980725.0
# Initialization：2　Learning times：52　Best SSE：56999980725.0
# Initialization：2　Learning times：53　Best SSE：56999980725.0
# Initialization：2　Learning times：54　Best SSE：56999980725.0
# Initialization：2　Learning times：55　Best SSE：56999980725.0
# Initialization：2　Learning times：56　Best SSE：56999980725.0
# Initialization：2　Learning times：57　Best SSE：56999980725.0
# Initialization：2　Learning times：58　Best SSE：56999980725.0
# Initialization：2　Learning times：59　Best SSE：56999980725.0
# Initialization：2　Learning times：60　Best SSE：56999980725.0
# Initialization：2　Learning times：61　Best SSE：56999980725.0
# Initialization：2　Learning times：62　Best SSE：56999980725.0
# Initialization：2　Learning times：63　Best SSE：56999980725.0
# Initialization：2　Learning times：64　Best SSE：56999980725.0
# Initialization：2　Learning times：65　Best SSE：56999980725.0
# Initialization：2　Learning times：66　Best SSE：56999980725.0
# Initialization：2　Learning times：67　Best SSE：56999980725.0
# Initialization：2　Learning times：68　Best SSE：56999980725.0
# Initialization：2　Learning times：69　Best SSE：56999980725.0
# Initialization：2　Learning times：70　Best SSE：56999980725.0
# Initialization：2　Learning times：71　Best SSE：56999980725.0
# Initialization：2　Learning times：72　Best SSE：56999980725.0
# Initialization：2　Learning times：73　Best SSE：56999980725.0
# Initialization：2　Learning times：74　Best SSE：56999980725.0
# Initialization：2　Learning times：75　Best SSE：56999980725.0
# Initialization：2　Learning times：76　Best SSE：56999980725.0
# Initialization：2　Learning times：77　Best SSE：56999980725.0
# Initialization：2　Learning times：78　Best SSE：56999980725.0
# Initialization：2　Learning times：79　Best SSE：56999980725.0
# Initialization：2　Learning times：80　Best SSE：56999980725.0
# Initialization：2　Learning times：81　Best SSE：56999980725.0
# Initialization：2　Learning times：82　Best SSE：56999980725.0
# Initialization：2　Learning times：83　Best SSE：56999980725.0
# Initialization：2　Learning times：84　Best SSE：56999980725.0
# Initialization：2　Learning times：85　Best SSE：56999980725.0
# Initialization：2　Learning times：86　Best SSE：56999980725.0
# Initialization：2　Learning times：87　Best SSE：56999980725.0
# Initialization：2　Learning times：88　Best SSE：56999980725.0
# Initialization：2　Learning times：89　Best SSE：56999980725.0
# Initialization：2　Learning times：90　Best SSE：56999980725.0
# Initialization：2　Learning times：91　Best SSE：56999980725.0
# Initialization：2　Learning times：92　Best SSE：56999980725.0
# Initialization：2　Learning times：93　Best SSE：56999980725.0
# Initialization：2　Learning times：94　Best SSE：56999980725.0
# Initialization：2　Learning times：95　Best SSE：56999980725.0
# Initialization：2　Learning times：96　Best SSE：56999980725.0
# Initialization：2　Learning times：97　Best SSE：56999980725.0
# Initialization：2　Learning times：98　Best SSE：56999980725.0
# Initialization：2　Learning times：99　Best SSE：56999980725.0
# Initialization：3　Learning times：0　Best SSE：56999980725.0
# Initialization：3　Learning times：1　Best SSE：56999980725.0
# Initialization：3　Learning times：2　Best SSE：56999980725.0
# Initialization：3　Learning times：3　Best SSE：56999980725.0
# Initialization：3　Learning times：4　Best SSE：56999980725.0
# Initialization：3　Learning times：5　Best SSE：56999980725.0
# Initialization：3　Learning times：6　Best SSE：56999980725.0
# Initialization：3　Learning times：7　Best SSE：56999980725.0
# Initialization：3　Learning times：8　Best SSE：56999980725.0
# Initialization：3　Learning times：9　Best SSE：56999980725.0
# Initialization：3　Learning times：10　Best SSE：56999980725.0
# Initialization：3　Learning times：11　Best SSE：56999980725.0
# Initialization：3　Learning times：12　Best SSE：56999980725.0
# Initialization：3　Learning times：13　Best SSE：56999980725.0
# Initialization：3　Learning times：14　Best SSE：56999980725.0
# Initialization：3　Learning times：15　Best SSE：56999980725.0
# Initialization：3　Learning times：16　Best SSE：56999980725.0
# Initialization：3　Learning times：17　Best SSE：56999980725.0
# Initialization：3　Learning times：18　Best SSE：56999980725.0
# Initialization：3　Learning times：19　Best SSE：56999980725.0
# Initialization：3　Learning times：20　Best SSE：56999980725.0
# Initialization：3　Learning times：21　Best SSE：56999980725.0
# Initialization：3　Learning times：22　Best SSE：56999980725.0
# Initialization：3　Learning times：23　Best SSE：56999980725.0
# Initialization：3　Learning times：24　Best SSE：56999980725.0
# Initialization：3　Learning times：25　Best SSE：56999980725.0
# Initialization：3　Learning times：26　Best SSE：56999980725.0
# Initialization：3　Learning times：27　Best SSE：56999980725.0
# Initialization：3　Learning times：28　Best SSE：56999980725.0
# Initialization：3　Learning times：29　Best SSE：56999980725.0
# Initialization：3　Learning times：30　Best SSE：56999980725.0
# Initialization：3　Learning times：31　Best SSE：56999980725.0
# Initialization：3　Learning times：32　Best SSE：56999980725.0
# Initialization：3　Learning times：33　Best SSE：56999980725.0
# Initialization：3　Learning times：34　Best SSE：56999980725.0
# Initialization：3　Learning times：35　Best SSE：56999980725.0
# Initialization：3　Learning times：36　Best SSE：56999980725.0
# Initialization：3　Learning times：37　Best SSE：56999980725.0
# Initialization：3　Learning times：38　Best SSE：56999980725.0
# Initialization：3　Learning times：39　Best SSE：56999980725.0
# Initialization：3　Learning times：40　Best SSE：56999980725.0
# Initialization：3　Learning times：41　Best SSE：56999980725.0
# Initialization：3　Learning times：42　Best SSE：56999980725.0
# Initialization：3　Learning times：43　Best SSE：56999980725.0
# Initialization：3　Learning times：44　Best SSE：56999980725.0
# Initialization：3　Learning times：45　Best SSE：56999980725.0
# Initialization：3　Learning times：46　Best SSE：56999980725.0
# Initialization：3　Learning times：47　Best SSE：56999980725.0
# Initialization：3　Learning times：48　Best SSE：56999980725.0
# Initialization：3　Learning times：49　Best SSE：56999980725.0
# Initialization：3　Learning times：50　Best SSE：56999980725.0
# Initialization：3　Learning times：51　Best SSE：56999980725.0
# Initialization：3　Learning times：52　Best SSE：56999980725.0
# Initialization：3　Learning times：53　Best SSE：56999980725.0
# Initialization：3　Learning times：54　Best SSE：56999980725.0
# Initialization：3　Learning times：55　Best SSE：56999980725.0
# Initialization：3　Learning times：56　Best SSE：56999980725.0
# Initialization：3　Learning times：57　Best SSE：56999980725.0
# Initialization：3　Learning times：58　Best SSE：56999980725.0
# Initialization：3　Learning times：59　Best SSE：56999980725.0
# Initialization：3　Learning times：60　Best SSE：56999980725.0
# Initialization：3　Learning times：61　Best SSE：56999980725.0
# Initialization：3　Learning times：62　Best SSE：56999980725.0
# Initialization：3　Learning times：63　Best SSE：56999980725.0
# Initialization：3　Learning times：64　Best SSE：56999980725.0
# Initialization：3　Learning times：65　Best SSE：56999980725.0
# Initialization：3　Learning times：66　Best SSE：56999980725.0
# Initialization：3　Learning times：67　Best SSE：56999980725.0
# Initialization：3　Learning times：68　Best SSE：56999980725.0
# Initialization：3　Learning times：69　Best SSE：56999980725.0
# Initialization：3　Learning times：70　Best SSE：56999980725.0
# Initialization：3　Learning times：71　Best SSE：56999980725.0
# Initialization：3　Learning times：72　Best SSE：56999980725.0
# Initialization：3　Learning times：73　Best SSE：56999980725.0
# Initialization：3　Learning times：74　Best SSE：56999980725.0
# Initialization：3　Learning times：75　Best SSE：56999980725.0
# Initialization：3　Learning times：76　Best SSE：56999980725.0
# Initialization：3　Learning times：77　Best SSE：56999980725.0
# Initialization：3　Learning times：78　Best SSE：56999980725.0
# Initialization：3　Learning times：79　Best SSE：56999980725.0
# Initialization：3　Learning times：80　Best SSE：56999980725.0
# Initialization：3　Learning times：81　Best SSE：56999980725.0
# Initialization：3　Learning times：82　Best SSE：56999980725.0
# Initialization：3　Learning times：83　Best SSE：56999980725.0
# Initialization：3　Learning times：84　Best SSE：56999980725.0
# Initialization：3　Learning times：85　Best SSE：56999980725.0
# Initialization：3　Learning times：86　Best SSE：56999980725.0
# Initialization：3　Learning times：87　Best SSE：56999980725.0
# Initialization：3　Learning times：88　Best SSE：56999980725.0
# Initialization：3　Learning times：89　Best SSE：56999980725.0
# Initialization：3　Learning times：90　Best SSE：56999980725.0
# Initialization：3　Learning times：91　Best SSE：56999980725.0
# Initialization：3　Learning times：92　Best SSE：56999980725.0
# Initialization：3　Learning times：93　Best SSE：56999980725.0
# Initialization：3　Learning times：94　Best SSE：56999980725.0
# Initialization：3　Learning times：95　Best SSE：56999980725.0
# Initialization：3　Learning times：96　Best SSE：56999980725.0
# Initialization：3　Learning times：97　Best SSE：56999980725.0
# Initialization：3　Learning times：98　Best SSE：56999980725.0
# Initialization：3　Learning times：99　Best SSE：56999980725.0
# Initialization：4　Learning times：0　Best SSE：56999980725.0
# Initialization：4　Learning times：1　Best SSE：56999980725.0
# Initialization：4　Learning times：2　Best SSE：56999980725.0
# Initialization：4　Learning times：3　Best SSE：56999980725.0
# Initialization：4　Learning times：4　Best SSE：56999980725.0
# Initialization：4　Learning times：5　Best SSE：56999980725.0
# Initialization：4　Learning times：6　Best SSE：56999980725.0
# Initialization：4　Learning times：7　Best SSE：56999980725.0
# Initialization：4　Learning times：8　Best SSE：56999980725.0
# Initialization：4　Learning times：9　Best SSE：56999980725.0
# Initialization：4　Learning times：10　Best SSE：56999980725.0
# Initialization：4　Learning times：11　Best SSE：56999980725.0
# Initialization：4　Learning times：12　Best SSE：56999980725.0
# Initialization：4　Learning times：13　Best SSE：56999980725.0
# Initialization：4　Learning times：14　Best SSE：56999980725.0
# Initialization：4　Learning times：15　Best SSE：56999980725.0
# Initialization：4　Learning times：16　Best SSE：56999980725.0
# Initialization：4　Learning times：17　Best SSE：56999980725.0
# Initialization：4　Learning times：18　Best SSE：56999980725.0
# Initialization：4　Learning times：19　Best SSE：56999980725.0
# Initialization：4　Learning times：20　Best SSE：56999980725.0
# Initialization：4　Learning times：21　Best SSE：56999980725.0
# Initialization：4　Learning times：22　Best SSE：56999980725.0
# Initialization：4　Learning times：23　Best SSE：56999980725.0
# Initialization：4　Learning times：24　Best SSE：56999980725.0
# Initialization：4　Learning times：25　Best SSE：56999980725.0
# Initialization：4　Learning times：26　Best SSE：56999980725.0
# Initialization：4　Learning times：27　Best SSE：56999980725.0
# Initialization：4　Learning times：28　Best SSE：56999980725.0
# Initialization：4　Learning times：29　Best SSE：56999980725.0
# Initialization：4　Learning times：30　Best SSE：56999980725.0
# Initialization：4　Learning times：31　Best SSE：56999980725.0
# Initialization：4　Learning times：32　Best SSE：56999980725.0
# Initialization：4　Learning times：33　Best SSE：56999980725.0
# Initialization：4　Learning times：34　Best SSE：56999980725.0
# Initialization：4　Learning times：35　Best SSE：56999980725.0
# Initialization：4　Learning times：36　Best SSE：56999980725.0
# Initialization：4　Learning times：37　Best SSE：56999980725.0
# Initialization：4　Learning times：38　Best SSE：56999980725.0
# Initialization：4　Learning times：39　Best SSE：56999980725.0
# Initialization：4　Learning times：40　Best SSE：56999980725.0
# Initialization：4　Learning times：41　Best SSE：56999980725.0
# Initialization：4　Learning times：42　Best SSE：56999980725.0
# Initialization：4　Learning times：43　Best SSE：56999980725.0
# Initialization：4　Learning times：44　Best SSE：56999980725.0
# Initialization：4　Learning times：45　Best SSE：56999980725.0
# Initialization：4　Learning times：46　Best SSE：56999980725.0
# Initialization：4　Learning times：47　Best SSE：56999980725.0
# Initialization：4　Learning times：48　Best SSE：56999980725.0
# Initialization：4　Learning times：49　Best SSE：56999980725.0
# Initialization：4　Learning times：50　Best SSE：56999980725.0
# Initialization：4　Learning times：51　Best SSE：56999980725.0
# Initialization：4　Learning times：52　Best SSE：56999980725.0
# Initialization：4　Learning times：53　Best SSE：56999980725.0
# Initialization：4　Learning times：54　Best SSE：56999980725.0
# Initialization：4　Learning times：55　Best SSE：56999980725.0
# Initialization：4　Learning times：56　Best SSE：56999980725.0
# Initialization：4　Learning times：57　Best SSE：56999980725.0
# Initialization：4　Learning times：58　Best SSE：56999980725.0
# Initialization：4　Learning times：59　Best SSE：56999980725.0
# Initialization：4　Learning times：60　Best SSE：56999980725.0
# Initialization：4　Learning times：61　Best SSE：56999980725.0
# Initialization：4　Learning times：62　Best SSE：56999980725.0
# Initialization：4　Learning times：63　Best SSE：56999980725.0
# Initialization：4　Learning times：64　Best SSE：56999980725.0
# Initialization：4　Learning times：65　Best SSE：56999980725.0
# Initialization：4　Learning times：66　Best SSE：56999980725.0
# Initialization：4　Learning times：67　Best SSE：56999980725.0
# Initialization：4　Learning times：68　Best SSE：56999980725.0
# Initialization：4　Learning times：69　Best SSE：56999980725.0
# Initialization：4　Learning times：70　Best SSE：56999980725.0
# Initialization：4　Learning times：71　Best SSE：56999980725.0
# Initialization：4　Learning times：72　Best SSE：56999980725.0
# Initialization：4　Learning times：73　Best SSE：56999980725.0
# Initialization：4　Learning times：74　Best SSE：56999980725.0
# Initialization：4　Learning times：75　Best SSE：56999980725.0
# Initialization：4　Learning times：76　Best SSE：56999980725.0
# Initialization：4　Learning times：77　Best SSE：56999980725.0
# Initialization：4　Learning times：78　Best SSE：56999980725.0
# Initialization：4　Learning times：79　Best SSE：56999980725.0
# Initialization：4　Learning times：80　Best SSE：56999980725.0
# Initialization：4　Learning times：81　Best SSE：56999980725.0
# Initialization：4　Learning times：82　Best SSE：56999980725.0
# Initialization：4　Learning times：83　Best SSE：56999980725.0
# Initialization：4　Learning times：84　Best SSE：56999980725.0
# Initialization：4　Learning times：85　Best SSE：56999980725.0
# Initialization：4　Learning times：86　Best SSE：56999980725.0
# Initialization：4　Learning times：87　Best SSE：56999980725.0
# Initialization：4　Learning times：88　Best SSE：56999980725.0
# Initialization：4　Learning times：89　Best SSE：56999980725.0
# Initialization：4　Learning times：90　Best SSE：56999980725.0
# Initialization：4　Learning times：91　Best SSE：56999980725.0
# Initialization：4　Learning times：92　Best SSE：56999980725.0
# Initialization：4　Learning times：93　Best SSE：56999980725.0
# Initialization：4　Learning times：94　Best SSE：56999980725.0
# Initialization：4　Learning times：95　Best SSE：56999980725.0
# Initialization：4　Learning times：96　Best SSE：56999980725.0
# Initialization：4　Learning times：97　Best SSE：56999980725.0
# Initialization：4　Learning times：98　Best SSE：56999980725.0
# Initialization：4　Learning times：99　Best SSE：56999980725.0
# [2 2 3 1 0 1 0 0 0 0 2 2 0 1 0 2 0 2 1 0 3 3 0 1 0 0 1 1 3 0 2 1 0 2 0 2 3
#  3 2 3 0 3 1 0 0 2 3 0 1 1 1 3 3 0 2 3 3 3 3 0 1 1 3 0 1 0 2 0 3 3 2 3 0 2
#  0 0 2 0 0 3 1 1 3 1 1 3 3 1 3 3 1 2 3 0 1 2 2 0 2 1 1 2 1 3 1 0 0 1 1 3 0
#  2 1 3 1 3 1 0 1 0 3 2 2 3 0 3 1 2 2 0 1 3 3 3 3 2 1 0 1 1 0 2 0 1 1 1 0 0
#  2 2 3 3 1 2 1 3 3 3 3 3 3 3 3 3 1 2 2 2 0 1 2 3 0 2 1 3 3 3 3 2 0 3 1 2 2
#  3 0 2 2 0 1 1 2 2 0 1 0 2 2 1 2 3 1 0 0 2 0 3 2 0 3 0 3 2 0 0 0 1 3 1 0 2
#  3 0 3 3 3 1 3 1 2 3 2 3 1 1 3 2 1 2 0 3 2 2 2 2 0 3 2 3 0 1 1 0 0 1 3 0 3
#  1 0 1 3 3 1 0 2 2 3 3 3 0 1 1 0 1 3 2 1 2 1 2 2 1 2 1 1 0 3 3 3 0 0 3 2 1
#  2 2 2 0 3 0 2 3 2 2 3 2 2 3 1 2 0 0 1 1 3 2 1 1 0 2 1 1 0 3 1 3 0 2 2 1 3
#  2 0 1 1 0 0 0 2 0 1 1 3 1 1 1 1 2 2 0 1 3 0 2 1 3 1 0 1 3 0 3 1 0 0 2 1 2
#  2 2 2 2 2 3 2 1 2 1 1 3 1 0 3 3 2 1 3 1 0 2 3 3 2 3 3 1 1 2 3 0 1 0 0 2 2
#  0 2 3 3 2 3 2 3 1 2 1 3 0 1 3 0 1 2 0 1 1 3 0 3 0 2 1 2 0 1 2 2 2 3 1 0 2
#  0 0 3 3 2 0 0 0 0 0 0 2 0 3 2 0 1 0 1 0 3 3 1 1 1 3 0 3 2 3 1 0 2 1 2 1 2
#  0 1 1 2 3 0 2 3 3 3 2 0 1 3 0 2 2 2 0]
# For n_clusters = 2 The average silhouette_score is : 0.7049787496083262
# For n_clusters = 3 The average silhouette_score is : 0.5882004012129721
# For n_clusters = 4 The average silhouette_score is : 0.6505186632729437
# For n_clusters = 5 The average silhouette_score is : 0.56376469026194
# For n_clusters = 6 The average silhouette_score is : 0.4504666294372765
# Estimated no. of clusters: 2
# Estimated no. of noise points: 0
